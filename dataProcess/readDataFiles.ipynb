# %%
import pandas as pd

# %%
commasep = pd.read_csv('data/2015-09-14_13-01-32__CommaSeparated.txt')
spacesep = pd.read_csv('data/2015-09-14_13-01-49__SpaceSeparated.txt',sep='\s+')

# %%
spacesep
# Out:
#      Year  Month  Day  Hour  Temp  DewTemp  Pressure  WindDir  WindSpeed  Sky  \
# 0    1912      4    1     6   114       94     10121      200        120    8
# 1    1912      4    1     9   146       96     10122      240        140    8
# 2    1912      4    2     6   172      122     10146      210         40    2
# 3    1912      4    2     9   193    -9999     10150      240        210    1
# 4    1912      4    2    12   188      125     10152      240        250    1
# ..    ...    ...  ...   ...   ...      ...       ...      ...        ...  ...
# 752  1912     12   30     9   118      106     10197       80         21    7
# 753  1912     12   30    12   140      106     10185       80         31    5
# 754  1912     12   30    15   112       84     10196       80         31    7
# 755  1912     12   31     6   142       87     10225      260         41    8
# 756  1912     12   31    15   146       83     10213      260         51    7
#
#      Precip1  Precip6
# ...

# %%
commasep
# Out:
#      Year  Month  Day  Hour  Temp  DewTemp  Pressure  WindDir  WindSpeed  Sky  \
# 0    1912      4    1     6   114       94     10121      200        120    8
# 1    1912      4    1     9   146       96     10122      240        140    8
# 2    1912      4    2     6   172      122     10146      210         40    2
# 3    1912      4    2     9   193    -9999     10150      240        210    1
# 4    1912      4    2    12   188      125     10152      240        250    1
# ..    ...    ...  ...   ...   ...      ...       ...      ...        ...  ...
# 752  1912     12   30     9   118      106     10197       80         21    7
# 753  1912     12   30    12   140      106     10185       80         31    5
# 754  1912     12   30    15   112       84     10196       80         31    7
# 755  1912     12   31     6   142       87     10225      260         41    8
# 756  1912     12   31    15   146       83     10213      260         51    7
#
#      Precip1  Precip6
# ...

# %%
exercise= pd.read_excel('data/original.xls')
#df=pandas.read_excel("C:\\Exercise\\Income-By-State1984.xls",skiprows=[0,1,2])
exercise[3:]
# Out:
#    Table H-8.  Median Household Income by State: 1984  Unnamed: 1
# 3                                           04000US01     17310.0
# 4                                           04000US02     32356.0
# 5                                           04000US04     21425.0
# 6                                           04000US05     15674.0
# 7                                           04000US06     25287.0
# 8                                           04000US08     25801.0
# 9                                           04000US09     29951.0
# 10                                          04000US10     25819.0
# 11                                          04000US12     19785.0
# 12                                          04000US13     19984.0
# 13                                          04000US15     28877.0
# 14                                          04000US16     21092.0
# 15                                          04000US17     23752.0
# ...

# %%
exercise[3:].to_csv('data/original.csv',index=None)
