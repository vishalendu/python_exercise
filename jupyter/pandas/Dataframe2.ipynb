# %%
import pandas as pd

# %%
emp = pd.read_csv('data/employees.csv')

# %%
emp
# Out:
#     First Name  Gender  Start Date Last Login Time  Salary  Bonus %  \
# 0      Douglas    Male    8/6/1993        12:42 PM   97308    6.945
# 1       Thomas    Male   3/31/1996         6:53 AM   61933    4.170
# 2        Maria  Female   4/23/1993        11:17 AM  130590   11.858
# 3        Jerry    Male    3/4/2005         1:00 PM  138705    9.340
# 4        Larry    Male   1/24/1998         4:47 PM  101004    1.389
# ..         ...     ...         ...             ...     ...      ...
# 995      Henry     NaN  11/23/2014         6:09 AM  132483   16.655
# 996    Phillip    Male   1/31/1984         6:30 AM   42392   19.675
# 997    Russell    Male   5/20/2013        12:39 PM   96914    1.421
# 998      Larry    Male   4/20/2013         4:45 PM   60500   11.985
# 999     Albert    Male   5/15/2012         6:24 PM  129949   10.169
#
#     Senior Management                  Team
# 0                True             Marketing
# 1                True                   NaN
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstName      933 non-null    object
#  1   Gender         855 non-null    object
#  2   StartDate      1000 non-null   object
#  3   LastLoginTime  1000 non-null   object
#  4   Salary         1000 non-null   int64
#  5   Bonus%         1000 non-null   float64
#  6   SeniorMgmt     933 non-null    object
#  7   Team           957 non-null    object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
emp.head(2)
# Out:
#   First Name Gender Start Date Last Login Time  Salary  Bonus %  \
# 0    Douglas   Male   8/6/1993        12:42 PM   97308    6.945
# 1     Thomas   Male  3/31/1996         6:53 AM   61933    4.170
#
#   Senior Management       Team
# 0              True  Marketing
# 1              True        NaN

# %%
emp.columns=['FirstName','Gender','StartDate','LastLoginTime','Salary','Bonus%',\
              'SeniorMgmt','Team']

# %%
emp.head(2)
# Out:
#   FirstName Gender  StartDate LastLoginTime  Salary  Bonus% SeniorMgmt  \
# 0   Douglas   Male   8/6/1993      12:42 PM   97308   6.945       True
# 1    Thomas   Male  3/31/1996       6:53 AM   61933   4.170       True
#
#         Team
# 0  Marketing
# 1        NaN

# %%
emp[['StartDate','LastLoginTime']].head(2)
# Out:
#    StartDate       LastLoginTime
# 0 1993-08-06 2020-03-26 12:42:00
# 1 1996-03-31 2020-03-26 06:53:00

# %%
emp['StartDate'] = pd.to_datetime(emp['StartDate'])
# if you only have time, pandas adds current date along with the timestamp
emp['LastLoginTime'] = pd.to_datetime(emp['LastLoginTime'])
emp['SeniorMgmt'] = emp['SeniorMgmt'].astype('bool')
emp['Gender'] = emp['Gender'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstName      933 non-null    object
#  1   Gender         855 non-null    category
#  2   StartDate      1000 non-null   datetime64[ns]
#  3   LastLoginTime  1000 non-null   datetime64[ns]
#  4   Salary         1000 non-null   int64
#  5   Bonus%         1000 non-null   float64
#  6   SeniorMgmt     1000 non-null   bool
#  7   Team           957 non-null    object
# dtypes: bool(1), category(1), datetime64[ns](2), float64(1), int64(1), object(2)
# memory usage: 49.0+ KB

# %% [markdown]
# ## another way to convert dates when loading the csv

# %%
emp = pd.read_csv('data/employees.csv',parse_dates=['Start Date','Last Login Time'])
emp.columns=['FirstName','Gender','StartDate','LastLoginTime','Salary','Bonus%',\
              'SeniorMgmt','Team']
emp['SeniorMgmt'] = emp['SeniorMgmt'].astype('bool')
emp['Team'] = emp['Team'].astype('category')
emp['Gender'] = emp['Gender'].astype('category')

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   FirstName      933 non-null    object
#  1   Gender         855 non-null    category
#  2   StartDate      1000 non-null   datetime64[ns]
#  3   LastLoginTime  1000 non-null   datetime64[ns]
#  4   Salary         1000 non-null   int64
#  5   Bonus%         1000 non-null   float64
#  6   SeniorMgmt     1000 non-null   bool
#  7   Team           957 non-null    category
# dtypes: bool(1), category(2), datetime64[ns](2), float64(1), int64(1), object(1)
# memory usage: 42.6+ KB

# %%
# male management employees sorted by descending salary
emp[(emp['Gender']=='Male') & (emp['SeniorMgmt']==True)].sort_values(by=['Salary'],ascending=False)
# Out:
#     FirstName Gender  StartDate       LastLoginTime  Salary  Bonus%  \
# 83      Shawn   Male 2005-09-23 2020-03-26 02:55:00  148115   6.539
# 851     Bobby   Male 1996-08-19 2020-03-26 01:16:00  147842  16.158
# 721    Harold   Male 2010-04-16 2020-03-26 05:13:00  147417  11.626
# 452     Scott   Male 2012-11-17 2020-03-26 14:47:00  146812   1.965
# 175    Willie   Male 1998-02-17 2020-03-26 20:20:00  146651   1.451
# ..        ...    ...        ...                 ...     ...     ...
# 949     Scott   Male 2011-08-20 2020-03-26 08:08:00   37385   8.226
# 25        NaN   Male 2012-10-08 2020-03-26 01:12:00   37076  18.576
# 964     Bruce   Male 1980-05-07 2020-03-26 20:00:00   35802  12.391
# 762     Terry   Male 2004-11-10 2020-03-26 04:33:00   35633   3.947
# 82     Steven   Male 1980-03-30 2020-03-26 21:20:00   35095   8.379
#
#      SeniorMgmt                  Team
# 83         True               Finance
# 851        True                   NaN
# ...

# %%
# check multiple 'OR' combinations using isin method
emp[emp['Team'].isin(['Sales','Distribution','Marketing'])]
# you can even pass another series from a DF into the isin method, to compare between two DFs
# Out:
#     FirstName  Gender  StartDate       LastLoginTime  Salary  Bonus%  \
# 0     Douglas    Male 1993-08-06 2020-03-26 12:42:00   97308   6.945
# 13       Gary    Male 2008-01-27 2020-03-26 23:40:00  109831   5.831
# 21    Matthew    Male 1995-09-05 2020-03-26 02:12:00  100612  13.645
# 26      Craig    Male 2000-02-27 2020-03-26 07:45:00   37598   7.757
# 35    Theresa  Female 2006-10-10 2020-03-26 01:12:00   85182  16.675
# ..        ...     ...        ...                 ...     ...     ...
# 986     Donna  Female 1982-11-26 2020-03-26 07:04:00   82871  17.999
# 991      Rose  Female 2002-08-25 2020-03-26 05:12:00  134505  11.051
# 994    George    Male 2013-06-21 2020-03-26 17:47:00   98874   4.479
# 995     Henry     NaN 2014-11-23 2020-03-26 06:09:00  132483  16.655
# 999    Albert    Male 2012-05-15 2020-03-26 18:24:00  129949  10.169
#
#      SeniorMgmt          Team
# 0          True     Marketing
# 13        False         Sales
# 21        False     Marketing
# ...

# %%
# getting columns with null values
emp[emp['FirstName'].isnull()]
# Out:
#     FirstName  Gender  StartDate       LastLoginTime  Salary  Bonus%  \
# 7         NaN  Female 2015-07-20 2020-03-26 10:43:00   45906  11.598
# 23        NaN    Male 2012-06-14 2020-03-26 16:19:00  125792   5.042
# 25        NaN    Male 2012-10-08 2020-03-26 01:12:00   37076  18.576
# 32        NaN    Male 1998-08-21 2020-03-26 14:27:00  122340   6.417
# 39        NaN    Male 2016-01-29 2020-03-26 02:33:00  122173   7.797
# ..        ...     ...        ...                 ...     ...     ...
# 902       NaN    Male 2001-05-23 2020-03-26 19:52:00  103877   6.322
# 925       NaN  Female 2000-08-23 2020-03-26 16:19:00   95866  19.388
# 946       NaN  Female 1985-09-15 2020-03-26 01:50:00  133472  16.941
# 947       NaN    Male 2012-07-30 2020-03-26 15:07:00  107351   5.329
# 951       NaN  Female 2010-09-14 2020-03-26 05:19:00  143638   9.662
#
#      SeniorMgmt             Team
# 7          True          Finance
# 23         True              NaN
# 25         True  Client Services
# ...

# %%
# getting columns with not null values
#emp[emp['FirstName'].isnull()==False]
emp[emp['FirstName'].notnull()]
# Out:
#     FirstName  Gender  StartDate       LastLoginTime  Salary  Bonus%  \
# 0     Douglas    Male 1993-08-06 2020-03-26 12:42:00   97308   6.945
# 1      Thomas    Male 1996-03-31 2020-03-26 06:53:00   61933   4.170
# 2       Maria  Female 1993-04-23 2020-03-26 11:17:00  130590  11.858
# 3       Jerry    Male 2005-03-04 2020-03-26 13:00:00  138705   9.340
# 4       Larry    Male 1998-01-24 2020-03-26 16:47:00  101004   1.389
# ..        ...     ...        ...                 ...     ...     ...
# 995     Henry     NaN 2014-11-23 2020-03-26 06:09:00  132483  16.655
# 996   Phillip    Male 1984-01-31 2020-03-26 06:30:00   42392  19.675
# 997   Russell    Male 2013-05-20 2020-03-26 12:39:00   96914   1.421
# 998     Larry    Male 2013-04-20 2020-03-26 16:45:00   60500  11.985
# 997    Russell    Male 2013-05-20 2020-03-26 12:39:00   96914   1.421
#
#      SeniorMgmt             Team
# 0          True        Marketing
# 3          True          Finance
# ...

# %%
emp[emp['FirstName'].duplicated()].sort_values(by='FirstName')
# second occurance onwards repeating values are considered as duplicates(keep='First')
# useful if the first entity is the one you want to considered, could be duplicate master data
# emp[emp['FirstName'].duplicated(keep='First')==False].sort_values(by='FirstName')


# last occurance is not considered duplicate (keep='Last') - useful if you have multiple values
# for the same entity and you want to take the last update...
# emp[emp['FirstName'].duplicated(keep='Last')==False].sort_values(by='FirstName')


# Remove all values that have duplicates
# emp[emp['FirstName'].duplicated(keep=False)==False].sort_values(by='FirstName')
# Out:
#     FirstName  Gender  StartDate       LastLoginTime  Salary  Bonus%  \
# 101     Aaron    Male 2012-02-17 2020-03-26 10:20:00   61602  11.849
# 137      Adam    Male 2011-05-21 2020-03-26 01:45:00   95327  15.120
# 53       Alan     NaN 2014-03-03 2020-03-26 13:28:00   40341  17.578
# 372    Albert    Male 1997-02-01 2020-03-26 16:20:00   67827  19.717
# 425     Alice  Female 1986-05-02 2020-03-26 01:50:00   51395   2.378
# ..        ...     ...        ...                 ...     ...     ...
# 433     Wanda  Female 2008-07-20 2020-03-26 13:44:00   65362   7.132
# 177     Wayne    Male 2012-04-07 2020-03-26 08:00:00  102652  14.085
# 127   William    Male 2002-09-29 2020-03-26 16:09:00   66521   5.830
# 112    Willie    Male 2003-11-27 2020-03-26 06:21:00   64363   4.023
# 7         NaN  Female 2015-07-20 2020-03-26 10:43:00   45906  11.598
#
#      SeniorMgmt             Team
# 101        True        Marketing
# 137       False     Distribution
# 53         True          Finance
# ...

# %%
# remove duplicates from second occurance onwards
emp.drop_duplicates(subset=['FirstName'],keep='first')['FirstName'].count()

# remove duplicates keep the last (latest) one
#emp.drop_duplicates(subset=['FirstName'],keep='last')['FirstName'].count()

# same for keep=False as mentioned above- remove any value that has duplicate

# you can also pass multiple values in subset, then the uniqeness will be 
# computed over multiple columns
emp.drop_duplicates(subset=['FirstName','Gender','Team'],keep='first')
# Out:
#     FirstName  Gender  StartDate       LastLoginTime  Salary  Bonus%  \
# 0     Douglas    Male 1993-08-06 2020-03-26 12:42:00   97308   6.945
# 1      Thomas    Male 1996-03-31 2020-03-26 06:53:00   61933   4.170
# 2       Maria  Female 1993-04-23 2020-03-26 11:17:00  130590  11.858
# 3       Jerry    Male 2005-03-04 2020-03-26 13:00:00  138705   9.340
# 4       Larry    Male 1998-01-24 2020-03-26 16:47:00  101004   1.389
# ..        ...     ...        ...                 ...     ...     ...
# 994    George    Male 2013-06-21 2020-03-26 17:47:00   98874   4.479
# 995     Henry     NaN 2014-11-23 2020-03-26 06:09:00  132483  16.655
# 996   Phillip    Male 1984-01-31 2020-03-26 06:30:00   42392  19.675
# 998     Larry    Male 2013-04-20 2020-03-26 16:45:00   60500  11.985
# 999    Albert    Male 2012-05-15 2020-03-26 18:24:00  129949  10.169
#
#      SeniorMgmt                  Team
# 0          True             Marketing
# 1          True                   NaN
# ...

# %%
emp['Team'].value_counts()
# Out:
# Client Services         106
# Finance                 102
# Business Development    101
# Marketing                98
# Product                  95
# Sales                    94
# Engineering              92
# Human Resources          91
# Distribution             90
# Legal                    88
# Name: Team, dtype: int64

# %% [markdown]
# Difference between len() and nunique()
# len counts NaN but nunique()  doesnt consider it as valid value, so it doesnt count it
#
# alternatively nunique(dropna=False) <- this will allow counting null as unique value
